# %% [markdown]
# <a href="https://colab.research.google.com/github/PhamVietLong-25021855/PhamVietLong_25021855_TDTT/blob/main/th%E1%BB%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input())
for i in range(n):
  print(i)
# Out:
# 5
# 0
# 1
# 2
# 3
# 4
